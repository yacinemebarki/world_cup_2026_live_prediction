# %%
import numpy as np
import pandas as pd
import os 
import re

# %% [markdown]
# ## extract the data

# %%
pattern1=r"matches"
matches=pd.DataFrame()
players=pd.DataFrame()
data="../data"
for dirc in os.listdir(data):
    path=os.path.join(data,dirc)
    if os.path.isdir(path):
        print(dirc)
        for file in os.listdir(path):
            if file=="players.csv" or file=="player_valuations.csv" :
                continue
            match=re.search(pattern1,file)
            if match:
                target_file=os.path.join(path,file)
                matches2=pd.read_csv(target_file)
                if file=="players":
                    print(file)
                if matches.empty:
                    matches=matches2
                else :
                    matches=pd.concat([matches,matches2])
            else :
                target_file=os.path.join(path,file)
                players2=pd.read_csv(target_file)
                if players.empty:
                    players=players2
                else :
                    players=pd.concat([players,players2])   
                 
matches
# Out:
# 2006
# additional
# 2018
# 2010
# 2002
# 2014
# 2022
#      timestamp              date_GMT    status  attendance  \
# 0   1149868800  Jun 09 2006 - 4:00pm  complete     66000.0
# 1   1149879600  Jun 09 2006 - 7:00pm  complete     52000.0
# 2   1149944400  Jun 10 2006 - 1:00pm  complete     48000.0
# 3   1149955200  Jun 10 2006 - 4:00pm  complete     62959.0
# 4   1149966000  Jun 10 2006 - 7:00pm  complete     49480.0
# ..         ...                   ...       ...         ...
# 59  1670698800  Dec 10 2022 - 7:00pm  complete         NaN
# 60  1670958000  Dec 13 2022 - 7:00pm  complete     88966.0
# 61  1671044400  Dec 14 2022 - 7:00pm  complete         NaN
# 62  1671289200  Dec 17 2022 - 3:00pm  complete         NaN
# 63  1671375600  Dec 18 2022 - 3:00pm  complete     88966.0
#
#          home_team_name away_team_name                        referee  \
# 0               Germany     Costa Rica                            NaN
# 1                Poland        Ecuador                            NaN
# 2               England       Paraguay                            NaN
# 3   Trinidad and Tobago         Sweden                            NaN
# 4             Argentina    Ivory Coast                            NaN
# ..                  ...            ...                            ...
# 59              England         France         Wilton Pereira Sampaio
# 60            Argentina        Croatia                 Daniele Orsato
# 61               France        Morocco  César Arturo Ramos Palazuelos
# 62              Croatia        Morocco  Abdulrahman Ibrahim Al Jassim
# 63            Argentina         France               Szymon Marciniak
#
#     Game Week  Pre-Match PPG (Home)  Pre-Match PPG (Away)  ...  \
# 0         1.0                  0.00                  0.00  ...
# 1         1.0                  0.00                  0.00  ...
# 2         1.0                  0.00                  0.00  ...
# 3         1.0                  0.00                  0.00  ...
# 4         1.0                  0.00                  0.00  ...
# ..        ...                   ...                   ...  ...
# 59        NaN                  2.50                  2.25  ...
# 60        NaN                  2.00                  1.40  ...
# 61        NaN                  2.40                  2.20  ...
# 62        NaN                  1.17                  1.83  ...
# 63        NaN                  2.17                  2.50  ...
#
#     odds_ft_home_team_win  odds_ft_draw  odds_ft_away_team_win  \
# 0                    0.00          0.00                   0.00
# 1                    0.00          0.00                   0.00
# 2                    0.00          0.00                   0.00
# 3                    0.00          0.00                   0.00
# 4                    0.00          0.00                   0.00
# ..                    ...           ...                    ...
# 59                   3.10          3.20                   2.38
# 60                   1.80          3.40                   5.00
# 61                   1.57          4.00                   6.75
# 62                   2.43          3.40                   3.10
# 63                   2.70          2.95                   2.65
#
#     odds_ft_over15  odds_ft_over25  odds_ft_over35  odds_ft_over45  \
# 0             0.00            0.00            0.00             0.0
# 1             0.00            0.00            0.00             0.0
# 2             0.00            0.00            0.00             0.0
# 3             0.00            0.00            0.00             0.0
# 4             0.00            0.00            0.00             0.0
# ..             ...             ...             ...             ...
# 59            1.32            2.10            3.40             6.3
# 60            1.52            2.48            4.50             9.0
# 61            1.40            2.25            1.79             9.5
# 62            1.26            2.07            2.98             5.7
# 63            1.45            2.35            4.30             7.5
#
#     odds_btts_yes odds_btts_no  \
# 0            0.00         0.00
# 1            0.00         0.00
# 2            0.00         0.00
# 3            0.00         0.00
# 4            0.00         0.00
# ..            ...          ...
# 59           1.80         1.95
# 60           2.25         1.57
# 61           2.25         1.57
# 62           1.67         2.10
# 63           2.00         1.75
#
#                                          stadium_name
# 0                                       Allianz Arena
# 1                                       VELTINS-Arena
# 2                                   Commerzbank-Arena
# 3                                   Signal-Iduna-Park
# 4                                    Volksparkstadion
# ..                                                ...
# 59                          Al Bayt Stadium (Al Khor)
# 60                     Lusail Iconic Stadium (Lusail)
# 61                          Al Bayt Stadium (Al Khor)
# 62  Khalifa International Stadium (Al Rayyan (Ar-R...
# 63                     Lusail Iconic Stadium (Lusail)
#
# [5926 rows x 66 columns]

# %%
players
# Out:
#                           full_name  age      birthday birthday_GMT  \
# 0                      Aaron Lennon   35  5.455548e+08   1987/04/16
# 1       Abdoulaye Mu00e9u00eftu00e9   41  3.396636e+08   1980/10/06
# 2             Abdul Kader Keu00efta   41  3.659292e+08   1981/08/06
# 3    Abdulaziz Mohammed Al Khathran   49  1.129500e+08   1973/07/31
# 4                  Adékambi Olufadé   42  3.160800e+08   1980/01/07
# ..                              ...  ...           ...          ...
# 817                  Yussuf Poulsen   31  7.716384e+08   1994/06/15
# 818                   Yuto Nagatomo   39  5.268672e+08   1986/09/12
# 819               Zakaria Aboukhlal   26  9.508320e+08   2000/02/18
# 820                     Zeno Debast   22  1.066954e+09   2003/10/24
# 821                Łukasz Skorupski   34  6.734016e+08   1991/05/05
#
#                           league season    position  Current Club  \
# 0    FIFA World Cup 2006 Germany   2006  Midfielder       England
# 1    FIFA World Cup 2006 Germany   2006    Defender   Ivory Coast
# 2    FIFA World Cup 2006 Germany   2006  Midfielder   Ivory Coast
# 3    FIFA World Cup 2006 Germany   2006  Midfielder  Saudi Arabia
# 4    FIFA World Cup 2006 Germany   2006     Forward          Togo
# ..                           ...    ...         ...           ...
# 817    FIFA World Cup 2022 Qatar   2022     Forward       Denmark
# 818    FIFA World Cup 2022 Qatar   2022    Defender         Japan
# 819    FIFA World Cup 2022 Qatar   2022     Forward       Morocco
# 820    FIFA World Cup 2022 Qatar   2022  Midfielder       Belgium
# 821    FIFA World Cup 2022 Qatar   2022  Goalkeeper        Poland
#
#      minutes_played_overall  minutes_played_home  ...  \
# 0                       102                  102  ...
# 1                       180                    0  ...
# 2                       150                   73  ...
# 3                       125                  125  ...
# 4                        31                   31  ...
# ..                      ...                  ...  ...
# 817                       0                    0  ...
# 818                     213                  156  ...
# 819                      73                    8  ...
# 820                       0                    0  ...
# 821                       0                    0  ...
#
#      annual_salary_eur_percentile clean_sheets_percentage_percentile_overall  \
# 0                             NaN                                        NaN
# 1                             NaN                                        NaN
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
# 4                             NaN                                        NaN
# ..                            ...                                        ...
# 817                           NaN                                        NaN
# 818                          46.0                                        7.0
# 819                          46.0                                       92.0
# 820                           NaN                                        NaN
# 821                           NaN                                        NaN
#
#      min_per_card_percentile_overall  cards_per90_percentile_overall  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 817                              NaN                             NaN
# 818                             21.0                            21.0
# 819                             21.0                            21.0
# 820                              NaN                             NaN
# 821                              NaN                             NaN
#
#      booked_over05_overall  booked_over05_percentage_overall  \
# 0                      NaN                               NaN
# 1                      NaN                               NaN
# 2                      NaN                               NaN
# 3                      NaN                               NaN
# 4                      NaN                               NaN
# ..                     ...                               ...
# 817                    NaN                               NaN
# 818                    0.0                               0.0
# 819                    0.0                               0.0
# 820                    NaN                               NaN
# 821                    NaN                               NaN
#
#      booked_over05_percentage_percentile_overall  shirt_number  \
# 0                                            NaN           NaN
# 1                                            NaN           NaN
# 2                                            NaN           NaN
# 3                                            NaN           NaN
# 4                                            NaN           NaN
# ..                                           ...           ...
# 817                                          NaN           NaN
# 818                                         21.0           5.0
# 819                                         21.0          14.0
# 820                                          NaN           NaN
# 821                                          NaN           NaN
#
#      annual_salary_gbp  annual_salary_usd
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ..                 ...                ...
# 817                NaN                NaN
# 818                0.0                0.0
# 819                0.0                0.0
# 820                NaN                NaN
# 821                NaN                NaN
#
# [65697 rows x 271 columns]

# %% [markdown]
# ## get essenteil info from players data

# %%
players["birthday_GMT"]=pd.to_datetime(players["birthday_GMT"],errors="coerce")
players["birthday_GMT"]=players["birthday_GMT"].dt.year
players
# Out:
#                           full_name  age      birthday  birthday_GMT  \
# 0                      Aaron Lennon   35  5.455548e+08        1987.0
# 1       Abdoulaye Mu00e9u00eftu00e9   41  3.396636e+08        1980.0
# 2             Abdul Kader Keu00efta   41  3.659292e+08        1981.0
# 3    Abdulaziz Mohammed Al Khathran   49  1.129500e+08        1973.0
# 4                  Adékambi Olufadé   42  3.160800e+08        1980.0
# ..                              ...  ...           ...           ...
# 817                  Yussuf Poulsen   31  7.716384e+08        1994.0
# 818                   Yuto Nagatomo   39  5.268672e+08        1986.0
# 819               Zakaria Aboukhlal   26  9.508320e+08        2000.0
# 820                     Zeno Debast   22  1.066954e+09        2003.0
# 821                Łukasz Skorupski   34  6.734016e+08        1991.0
#
#                           league season    position  Current Club  \
# 0    FIFA World Cup 2006 Germany   2006  Midfielder       England
# 1    FIFA World Cup 2006 Germany   2006    Defender   Ivory Coast
# 2    FIFA World Cup 2006 Germany   2006  Midfielder   Ivory Coast
# 3    FIFA World Cup 2006 Germany   2006  Midfielder  Saudi Arabia
# 4    FIFA World Cup 2006 Germany   2006     Forward          Togo
# ..                           ...    ...         ...           ...
# 817    FIFA World Cup 2022 Qatar   2022     Forward       Denmark
# 818    FIFA World Cup 2022 Qatar   2022    Defender         Japan
# 819    FIFA World Cup 2022 Qatar   2022     Forward       Morocco
# 820    FIFA World Cup 2022 Qatar   2022  Midfielder       Belgium
# 821    FIFA World Cup 2022 Qatar   2022  Goalkeeper        Poland
#
#      minutes_played_overall  minutes_played_home  ...  \
# 0                       102                  102  ...
# 1                       180                    0  ...
# 2                       150                   73  ...
# 3                       125                  125  ...
# 4                        31                   31  ...
# ..                      ...                  ...  ...
# 817                       0                    0  ...
# 818                     213                  156  ...
# 819                      73                    8  ...
# 820                       0                    0  ...
# 821                       0                    0  ...
#
#      annual_salary_eur_percentile clean_sheets_percentage_percentile_overall  \
# 0                             NaN                                        NaN
# 1                             NaN                                        NaN
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
# 4                             NaN                                        NaN
# ..                            ...                                        ...
# 817                           NaN                                        NaN
# 818                          46.0                                        7.0
# 819                          46.0                                       92.0
# 820                           NaN                                        NaN
# 821                           NaN                                        NaN
#
#      min_per_card_percentile_overall  cards_per90_percentile_overall  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 817                              NaN                             NaN
# 818                             21.0                            21.0
# 819                             21.0                            21.0
# 820                              NaN                             NaN
# 821                              NaN                             NaN
#
#      booked_over05_overall  booked_over05_percentage_overall  \
# 0                      NaN                               NaN
# 1                      NaN                               NaN
# 2                      NaN                               NaN
# 3                      NaN                               NaN
# 4                      NaN                               NaN
# ..                     ...                               ...
# 817                    NaN                               NaN
# 818                    0.0                               0.0
# 819                    0.0                               0.0
# 820                    NaN                               NaN
# 821                    NaN                               NaN
#
#      booked_over05_percentage_percentile_overall  shirt_number  \
# 0                                            NaN           NaN
# 1                                            NaN           NaN
# 2                                            NaN           NaN
# 3                                            NaN           NaN
# 4                                            NaN           NaN
# ..                                           ...           ...
# 817                                          NaN           NaN
# 818                                         21.0           5.0
# 819                                         21.0          14.0
# 820                                          NaN           NaN
# 821                                          NaN           NaN
#
#      annual_salary_gbp  annual_salary_usd
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ..                 ...                ...
# 817                NaN                NaN
# 818                0.0                0.0
# 819                0.0                0.0
# 820                NaN                NaN
# 821                NaN                NaN
#
# [65697 rows x 271 columns]

# %%
players
# Out:
#                           full_name  age      birthday  birthday_GMT  \
# 0                      Aaron Lennon   35  5.455548e+08        1987.0
# 1       Abdoulaye Mu00e9u00eftu00e9   41  3.396636e+08        1980.0
# 2             Abdul Kader Keu00efta   41  3.659292e+08        1981.0
# 3    Abdulaziz Mohammed Al Khathran   49  1.129500e+08        1973.0
# 4                  Adékambi Olufadé   42  3.160800e+08        1980.0
# ..                              ...  ...           ...           ...
# 817                  Yussuf Poulsen   31  7.716384e+08        1994.0
# 818                   Yuto Nagatomo   39  5.268672e+08        1986.0
# 819               Zakaria Aboukhlal   26  9.508320e+08        2000.0
# 820                     Zeno Debast   22  1.066954e+09        2003.0
# 821                Łukasz Skorupski   34  6.734016e+08        1991.0
#
#                           league season    position  Current Club  \
# 0    FIFA World Cup 2006 Germany   2006  Midfielder       England
# 1    FIFA World Cup 2006 Germany   2006    Defender   Ivory Coast
# 2    FIFA World Cup 2006 Germany   2006  Midfielder   Ivory Coast
# 3    FIFA World Cup 2006 Germany   2006  Midfielder  Saudi Arabia
# 4    FIFA World Cup 2006 Germany   2006     Forward          Togo
# ..                           ...    ...         ...           ...
# 817    FIFA World Cup 2022 Qatar   2022     Forward       Denmark
# 818    FIFA World Cup 2022 Qatar   2022    Defender         Japan
# 819    FIFA World Cup 2022 Qatar   2022     Forward       Morocco
# 820    FIFA World Cup 2022 Qatar   2022  Midfielder       Belgium
# 821    FIFA World Cup 2022 Qatar   2022  Goalkeeper        Poland
#
#      minutes_played_overall  minutes_played_home  ...  \
# 0                       102                  102  ...
# 1                       180                    0  ...
# 2                       150                   73  ...
# 3                       125                  125  ...
# 4                        31                   31  ...
# ..                      ...                  ...  ...
# 817                       0                    0  ...
# 818                     213                  156  ...
# 819                      73                    8  ...
# 820                       0                    0  ...
# 821                       0                    0  ...
#
#      annual_salary_eur_percentile clean_sheets_percentage_percentile_overall  \
# 0                             NaN                                        NaN
# 1                             NaN                                        NaN
# 2                             NaN                                        NaN
# 3                             NaN                                        NaN
# 4                             NaN                                        NaN
# ..                            ...                                        ...
# 817                           NaN                                        NaN
# 818                          46.0                                        7.0
# 819                          46.0                                       92.0
# 820                           NaN                                        NaN
# 821                           NaN                                        NaN
#
#      min_per_card_percentile_overall  cards_per90_percentile_overall  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 817                              NaN                             NaN
# 818                             21.0                            21.0
# 819                             21.0                            21.0
# 820                              NaN                             NaN
# 821                              NaN                             NaN
#
#      booked_over05_overall  booked_over05_percentage_overall  \
# 0                      NaN                               NaN
# 1                      NaN                               NaN
# 2                      NaN                               NaN
# 3                      NaN                               NaN
# 4                      NaN                               NaN
# ..                     ...                               ...
# 817                    NaN                               NaN
# 818                    0.0                               0.0
# 819                    0.0                               0.0
# 820                    NaN                               NaN
# 821                    NaN                               NaN
#
#      booked_over05_percentage_percentile_overall  shirt_number  \
# 0                                            NaN           NaN
# 1                                            NaN           NaN
# 2                                            NaN           NaN
# 3                                            NaN           NaN
# 4                                            NaN           NaN
# ..                                           ...           ...
# 817                                          NaN           NaN
# 818                                         21.0           5.0
# 819                                         21.0          14.0
# 820                                          NaN           NaN
# 821                                          NaN           NaN
#
#      annual_salary_gbp  annual_salary_usd
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
# ..                 ...                ...
# 817                NaN                NaN
# 818                0.0                0.0
# 819                0.0                0.0
# 820                NaN                NaN
# 821                NaN                NaN
#
# [65697 rows x 271 columns]

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 65697 entries, 0 to 821
# Columns: 271 entries, full_name to annual_salary_usd
# dtypes: float64(232), int64(32), object(7)
# memory usage: 136.3+ MB

# %%
players_summary=pd.DataFrame({
    "Data type":players.dtypes,
    "missing value":players.isna().sum()
    }
)
players_summary
# Out:
#                                             Data type  missing value
# full_name                                      object             16
# age                                             int64              0
# birthday                                      float64            106
# birthday_GMT                                  float64            106
# league                                         object              0
# ...                                               ...            ...
# booked_over05_percentage_overall              float64          48864
# booked_over05_percentage_percentile_overall   float64          48864
# shirt_number                                   object          48993
# annual_salary_gbp                             float64          48864
# annual_salary_usd                             float64          48864
#
# [271 rows x 2 columns]

# %%
n=len(players_summary)
for i in range(n):
    print(players_summary.iloc[i])
# Out:
# Data type        object
# missing value        16
# Name: full_name, dtype: object
# Data type        int64
# missing value        0
# Name: age, dtype: object
# Data type        float64
# missing value        106
# Name: birthday, dtype: object
# Data type        float64
# missing value        106
# Name: birthday_GMT, dtype: object
# Data type        object
# missing value         0
# Name: league, dtype: object
# Data type        object
# missing value         0
# Name: season, dtype: object
# Data type        object
# missing value         0
# Name: position, dtype: object
# Data type        object
# missing value         0
# Name: Current Club, dtype: object
# Data type        int64
# missing value        0
# Name: minutes_played_overall, dtype: object
# Data type        int64
# missing value        0
# Name: minutes_played_home, dtype: object
# Data type        int64
# missing value        0
# Name: minutes_played_away, dtype: object
# Data type        object
# missing value        58
# Name: nationality, dtype: object
# Data type        int64
# missing value        0
# Name: appearances_overall, dtype: object
# Data type        int64
# missing value        0
# Name: appearances_home, dtype: object
# Data type        int64
# missing value        0
# Name: appearances_away, dtype: object
# Data type        int64
# missing value        0
# Name: goals_overall, dtype: object
# Data type        int64
# missing value        0
# Name: goals_home, dtype: object
# Data type        int64
# missing value        0
# Name: goals_away, dtype: object
# Data type        int64
# missing value        0
# Name: assists_overall, dtype: object
# Data type        int64
# missing value        0
# Name: assists_home, dtype: object
# Data type        int64
# missing value        0
# Name: assists_away, dtype: object
# Data type        int64
# missing value        0
# Name: penalty_goals, dtype: object
# Data type        int64
# missing value        0
# Name: penalty_misses, dtype: object
# Data type        int64
# missing value        0
# Name: clean_sheets_overall, dtype: object
# Data type        int64
# missing value        0
# Name: clean_sheets_home, dtype: object
# Data type        int64
# missing value        0
# Name: clean_sheets_away, dtype: object
# Data type        int64
# missing value        0
# Name: conceded_overall, dtype: object
# Data type        int64
# missing value        0
# Name: conceded_home, dtype: object
# Data type        int64
# missing value        0
# Name: conceded_away, dtype: object
# Data type        int64
# missing value        0
# Name: yellow_cards_overall, dtype: object
# Data type        int64
# missing value        0
# Name: red_cards_overall, dtype: object
# Data type        float64
# missing value          0
# Name: goals_involved_per_90_overall, dtype: object
# Data type        float64
# missing value          0
# Name: assists_per_90_overall, dtype: object
# Data type        float64
# missing value          0
# Name: goals_per_90_overall, dtype: object
# Data type        float64
# missing value          0
# Name: goals_per_90_home, dtype: object
# Data type        float64
# missing value          0
# Name: goals_per_90_away, dtype: object
# Data type        int64
# missing value        0
# Name: min_per_goal_overall, dtype: object
# Data type        float64
# missing value          0
# Name: conceded_per_90_overall, dtype: object
# Data type        int64
# missing value        0
# Name: min_per_conceded_overall, dtype: object
# Data type        int64
# missing value        0
# Name: min_per_match, dtype: object
# Data type        int64
# missing value        0
# Name: min_per_card_overall, dtype: object
# Data type        int64
# missing value        0
# Name: min_per_assist_overall, dtype: object
# Data type        float64
# missing value          0
# Name: cards_per_90_overall, dtype: object
# Data type        int64
# missing value        0
# Name: rank_in_league_top_attackers, dtype: object
# Data type        int64
# missing value        0
# Name: rank_in_league_top_midfielders, dtype: object
# Data type        int64
# missing value        0
# Name: rank_in_league_top_defenders, dtype: object
# Data type        int64
# missing value        0
# Name: rank_in_club_top_scorer, dtype: object
# Data type        float64
# missing value      48864
# Name: annual_salary_eur, dtype: object
# Data type        float64
# missing value      48864
# Name: average_rating_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: assists_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: assists_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: passes_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: passes_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: passes_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: passes_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: passes_completed_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: passes_completed_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pass_completion_rate_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: passes_completed_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: passes_completed_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: short_passes_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: long_passes_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: key_passes_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: key_passes_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: through_passes_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: crosses_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: tackles_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: tackles_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: tackles_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: tackles_successful_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dispossesed_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: possession_regained_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pressures_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: saves_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: interceptions_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_successful_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_faced_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_per_goal_scored_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_off_target_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: distance_travelled_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_on_target_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: xg_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: chances_created_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_won_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: possession_regained_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: possession_regained_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: possession_regained_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      65697
# Name: additional_info, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_on_target_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_on_target_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_on_target_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_off_target_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_off_target_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_off_target_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: games_subbed_out, dtype: object
# Data type        float64
# missing value      48864
# Name: games_subbed_in, dtype: object
# Data type        float64
# missing value      48864
# Name: games_started, dtype: object
# Data type        float64
# missing value      48864
# Name: tackles_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: tackles_successful_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: tackles_successful_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: tackles_successful_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: interceptions_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: interceptions_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: interceptions_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: crosses_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: cross_completion_rate_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: crosses_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: crosses_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: through_passes_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: through_passes_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: through_passes_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: long_passes_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: long_passes_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: long_passes_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: short_passes_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: short_passes_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: short_passes_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: key_passes_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: key_passes_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_successful_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_successful_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_successful_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: chances_created_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: chances_created_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: chances_created_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: saves_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: save_percentage_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: saves_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: saves_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_faced_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_per_goal_conceded_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: conceded_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_faced_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shots_faced_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      65697
# Name: xg_faced_per_90_overall, dtype: object
# Data type        float64
# missing value      65697
# Name: xg_faced_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      65697
# Name: xg_faced_per_game_overall, dtype: object
# Data type        float64
# missing value      65697
# Name: xg_faced_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: save_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pressures_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pressures_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pressures_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: xg_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: market_value, dtype: object
# Data type        float64
# missing value      48864
# Name: market_value_percentile, dtype: object
# Data type        float64
# missing value      48864
# Name: pass_completion_rate_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shot_accuraccy_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shot_accuraccy_percentage_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbled_past_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbled_past_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbled_past_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbled_past_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_successful_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dribbles_successful_percentage_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pen_scored_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pen_missed_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: inside_box_saves_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: blocks_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: blocks_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: blocks_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: blocks_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: ratings_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: clearances_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: clearances_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: clearances_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pen_committed_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pen_save_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pen_committed_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pen_committed_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pen_committed_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pens_saved_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: pens_taken_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: hit_woodwork_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: hit_woodwork_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: hit_woodwork_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: punches_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: punches_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: punches_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: offsides_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: offsides_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: offsides_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: penalties_won_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shot_conversion_rate_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: shot_conversion_rate_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: minutes_played_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: matches_played_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: min_per_goal_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: min_per_conceded_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: xa_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: xa_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: xa_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: xa_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: npxg_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: npxg_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: npxg_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: npxg_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: fouls_drawn_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: fouls_drawn_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: fouls_drawn_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: fouls_drawn_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: fouls_committed_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: fouls_committed_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: fouls_committed_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: fouls_committed_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: xg_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: xg_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: average_rating_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: clearances_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: hit_woodwork_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: punches_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: offsides_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_won_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_won_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_won_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: aerial_duels_won_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_won_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_won_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_won_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_won_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: duels_won_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dispossesed_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dispossesed_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: dispossesed_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: progressive_passes_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: cross_completion_rate_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: distance_travelled_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: distance_travelled_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: distance_travelled_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: accurate_crosses_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: accurate_crosses_per_game_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: accurate_crosses_per_90_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: accurate_crosses_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: games_started_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: games_subbed_in_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: games_subbed_out_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: hattricks_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: two_goals_in_a_game_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: three_goals_in_a_game_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: two_goals_in_a_game_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: three_goals_in_a_game_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: goals_involved_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: goals_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: goals_per90_percentile_away, dtype: object
# Data type        float64
# missing value      48864
# Name: goals_per90_percentile_home, dtype: object
# Data type        float64
# missing value      48864
# Name: man_of_the_match_total_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: annual_salary_eur_percentile, dtype: object
# Data type        float64
# missing value      48864
# Name: clean_sheets_percentage_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: min_per_card_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: cards_per90_percentile_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: booked_over05_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: booked_over05_percentage_overall, dtype: object
# Data type        float64
# missing value      48864
# Name: booked_over05_percentage_percentile_overall, dtype: object
# Data type        object
# missing value     48993
# Name: shirt_number, dtype: object
# Data type        float64
# missing value      48864
# Name: annual_salary_gbp, dtype: object
# Data type        float64
# missing value      48864
# Name: annual_salary_usd, dtype: object

# %%
players["rank_in_league_top_midfielders"]
# Out:
# 0     -1
# 1     -1
# 2     -1
# 3     -1
# 4     -1
#       ..
# 817   -1
# 818   -1
# 819   -1
# 820   -1
# 821   -1
# Name: rank_in_league_top_midfielders, Length: 65697, dtype: int64

# %%
players_res=players[["full_name","age","birthday_GMT","season","Current Club"]]

# %%
players=players[["age","birthday_GMT","season","Current Club"]]
players=players.reset_index()

# %%
players=players.drop(columns=["index"])
players
# Out:
#        age  birthday_GMT season  Current Club
# 0       35        1987.0   2006       England
# 1       41        1980.0   2006   Ivory Coast
# 2       41        1981.0   2006   Ivory Coast
# 3       49        1973.0   2006  Saudi Arabia
# 4       42        1980.0   2006          Togo
# ...    ...           ...    ...           ...
# 65692   31        1994.0   2022       Denmark
# 65693   39        1986.0   2022         Japan
# 65694   26        2000.0   2022       Morocco
# 65695   22        2003.0   2022       Belgium
# 65696   34        1991.0   2022        Poland
#
# [65697 rows x 4 columns]

# %%
print(players.dtypes)
# Out:
# age               int64
# birthday_GMT    float64
# season           object
# Current Club     object
# dtype: object

# %%
players["season"]=pd.to_numeric(players["season"], errors="coerce")
players["age"]=players.apply(lambda row:(row["season"]-row["birthday_GMT"]),axis=1)
players
# Out:
#         age  birthday_GMT  season  Current Club
# 0      19.0        1987.0  2006.0       England
# 1      26.0        1980.0  2006.0   Ivory Coast
# 2      25.0        1981.0  2006.0   Ivory Coast
# 3      33.0        1973.0  2006.0  Saudi Arabia
# 4      26.0        1980.0  2006.0          Togo
# ...     ...           ...     ...           ...
# 65692  28.0        1994.0  2022.0       Denmark
# 65693  36.0        1986.0  2022.0         Japan
# 65694  22.0        2000.0  2022.0       Morocco
# 65695  19.0        2003.0  2022.0       Belgium
# 65696  31.0        1991.0  2022.0        Poland
#
# [65697 rows x 4 columns]

# %%
players=players.groupby(["Current Club","season"])["age"].mean()
players=players.reset_index()
players
# Out:
#          Current Club  season        age
# 0         Afghanistan  2021.0  27.047619
# 1         Afghanistan  2022.0  28.000000
# 2         Afghanistan  2024.0  27.000000
# 3         Afghanistan  2025.0  27.142857
# 4         Afghanistan  2026.0  28.592593
# ...               ...     ...        ...
# 1766         Zimbabwe  2024.0  26.095238
# 1767         Zimbabwe  2025.0  27.764706
# 1768         Zimbabwe  2026.0  29.061224
# 1769  Étoile du Congo  2022.0  25.157895
# 1770  Étoile du Congo  2026.0  26.942857
#
# [1771 rows x 3 columns]

# %% [markdown]
# ## get the essentiel info from matches data

# %%
matches
# Out:
#      timestamp              date_GMT    status  attendance  \
# 0   1149868800  Jun 09 2006 - 4:00pm  complete     66000.0
# 1   1149879600  Jun 09 2006 - 7:00pm  complete     52000.0
# 2   1149944400  Jun 10 2006 - 1:00pm  complete     48000.0
# 3   1149955200  Jun 10 2006 - 4:00pm  complete     62959.0
# 4   1149966000  Jun 10 2006 - 7:00pm  complete     49480.0
# ..         ...                   ...       ...         ...
# 59  1670698800  Dec 10 2022 - 7:00pm  complete         NaN
# 60  1670958000  Dec 13 2022 - 7:00pm  complete     88966.0
# 61  1671044400  Dec 14 2022 - 7:00pm  complete         NaN
# 62  1671289200  Dec 17 2022 - 3:00pm  complete         NaN
# 63  1671375600  Dec 18 2022 - 3:00pm  complete     88966.0
#
#          home_team_name away_team_name                        referee  \
# 0               Germany     Costa Rica                            NaN
# 1                Poland        Ecuador                            NaN
# 2               England       Paraguay                            NaN
# 3   Trinidad and Tobago         Sweden                            NaN
# 4             Argentina    Ivory Coast                            NaN
# ..                  ...            ...                            ...
# 59              England         France         Wilton Pereira Sampaio
# 60            Argentina        Croatia                 Daniele Orsato
# 61               France        Morocco  César Arturo Ramos Palazuelos
# 62              Croatia        Morocco  Abdulrahman Ibrahim Al Jassim
# 63            Argentina         France               Szymon Marciniak
#
#     Game Week  Pre-Match PPG (Home)  Pre-Match PPG (Away)  ...  \
# 0         1.0                  0.00                  0.00  ...
# 1         1.0                  0.00                  0.00  ...
# 2         1.0                  0.00                  0.00  ...
# 3         1.0                  0.00                  0.00  ...
# 4         1.0                  0.00                  0.00  ...
# ..        ...                   ...                   ...  ...
# 59        NaN                  2.50                  2.25  ...
# 60        NaN                  2.00                  1.40  ...
# 61        NaN                  2.40                  2.20  ...
# 62        NaN                  1.17                  1.83  ...
# 63        NaN                  2.17                  2.50  ...
#
#     odds_ft_home_team_win  odds_ft_draw  odds_ft_away_team_win  \
# 0                    0.00          0.00                   0.00
# 1                    0.00          0.00                   0.00
# 2                    0.00          0.00                   0.00
# 3                    0.00          0.00                   0.00
# 4                    0.00          0.00                   0.00
# ..                    ...           ...                    ...
# 59                   3.10          3.20                   2.38
# 60                   1.80          3.40                   5.00
# 61                   1.57          4.00                   6.75
# 62                   2.43          3.40                   3.10
# 63                   2.70          2.95                   2.65
#
#     odds_ft_over15  odds_ft_over25  odds_ft_over35  odds_ft_over45  \
# 0             0.00            0.00            0.00             0.0
# 1             0.00            0.00            0.00             0.0
# 2             0.00            0.00            0.00             0.0
# 3             0.00            0.00            0.00             0.0
# 4             0.00            0.00            0.00             0.0
# ..             ...             ...             ...             ...
# 59            1.32            2.10            3.40             6.3
# 60            1.52            2.48            4.50             9.0
# 61            1.40            2.25            1.79             9.5
# 62            1.26            2.07            2.98             5.7
# 63            1.45            2.35            4.30             7.5
#
#     odds_btts_yes odds_btts_no  \
# 0            0.00         0.00
# 1            0.00         0.00
# 2            0.00         0.00
# 3            0.00         0.00
# 4            0.00         0.00
# ..            ...          ...
# 59           1.80         1.95
# 60           2.25         1.57
# 61           2.25         1.57
# 62           1.67         2.10
# 63           2.00         1.75
#
#                                          stadium_name
# 0                                       Allianz Arena
# 1                                       VELTINS-Arena
# 2                                   Commerzbank-Arena
# 3                                   Signal-Iduna-Park
# 4                                    Volksparkstadion
# ..                                                ...
# 59                          Al Bayt Stadium (Al Khor)
# 60                     Lusail Iconic Stadium (Lusail)
# 61                          Al Bayt Stadium (Al Khor)
# 62  Khalifa International Stadium (Al Rayyan (Ar-R...
# 63                     Lusail Iconic Stadium (Lusail)
#
# [5926 rows x 66 columns]

# %%
matches["date_GMT"]=pd.to_datetime(matches["date_GMT"],errors="coerce")
matches["season"]=matches["date_GMT"].dt.year
matches["hour"]=matches["date_GMT"].dt.hour
matches
# Out:
# /tmp/ipykernel_6541/3995122214.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   matches["date_GMT"]=pd.to_datetime(matches["date_GMT"],errors="coerce")
#      timestamp            date_GMT    status  attendance       home_team_name  \
# 0   1149868800 2006-06-09 16:00:00  complete     66000.0              Germany
# 1   1149879600 2006-06-09 19:00:00  complete     52000.0               Poland
# 2   1149944400 2006-06-10 13:00:00  complete     48000.0              England
# 3   1149955200 2006-06-10 16:00:00  complete     62959.0  Trinidad and Tobago
# 4   1149966000 2006-06-10 19:00:00  complete     49480.0            Argentina
# ..         ...                 ...       ...         ...                  ...
# 59  1670698800 2022-12-10 19:00:00  complete         NaN              England
# 60  1670958000 2022-12-13 19:00:00  complete     88966.0            Argentina
# 61  1671044400 2022-12-14 19:00:00  complete         NaN               France
# 62  1671289200 2022-12-17 15:00:00  complete         NaN              Croatia
# 63  1671375600 2022-12-18 15:00:00  complete     88966.0            Argentina
#
#    away_team_name                        referee  Game Week  \
# 0      Costa Rica                            NaN        1.0
# 1         Ecuador                            NaN        1.0
# 2        Paraguay                            NaN        1.0
# 3          Sweden                            NaN        1.0
# 4     Ivory Coast                            NaN        1.0
# ..            ...                            ...        ...
# 59         France         Wilton Pereira Sampaio        NaN
# 60        Croatia                 Daniele Orsato        NaN
# 61        Morocco  César Arturo Ramos Palazuelos        NaN
# 62        Morocco  Abdulrahman Ibrahim Al Jassim        NaN
# 63         France               Szymon Marciniak        NaN
#
#     Pre-Match PPG (Home)  Pre-Match PPG (Away)  ...  odds_ft_away_team_win  \
# 0                   0.00                  0.00  ...                   0.00
# 1                   0.00                  0.00  ...                   0.00
# 2                   0.00                  0.00  ...                   0.00
# 3                   0.00                  0.00  ...                   0.00
# 4                   0.00                  0.00  ...                   0.00
# ..                   ...                   ...  ...                    ...
# 59                  2.50                  2.25  ...                   2.38
# 60                  2.00                  1.40  ...                   5.00
# 61                  2.40                  2.20  ...                   6.75
# 62                  1.17                  1.83  ...                   3.10
# 63                  2.17                  2.50  ...                   2.65
#
#     odds_ft_over15  odds_ft_over25  odds_ft_over35  odds_ft_over45  \
# 0             0.00            0.00            0.00             0.0
# 1             0.00            0.00            0.00             0.0
# 2             0.00            0.00            0.00             0.0
# 3             0.00            0.00            0.00             0.0
# 4             0.00            0.00            0.00             0.0
# ..             ...             ...             ...             ...
# 59            1.32            2.10            3.40             6.3
# 60            1.52            2.48            4.50             9.0
# 61            1.40            2.25            1.79             9.5
# 62            1.26            2.07            2.98             5.7
# 63            1.45            2.35            4.30             7.5
#
#     odds_btts_yes  odds_btts_no  \
# 0            0.00          0.00
# 1            0.00          0.00
# 2            0.00          0.00
# 3            0.00          0.00
# 4            0.00          0.00
# ..            ...           ...
# 59           1.80          1.95
# 60           2.25          1.57
# 61           2.25          1.57
# 62           1.67          2.10
# 63           2.00          1.75
#
#                                          stadium_name season hour
# 0                                       Allianz Arena   2006   16
# 1                                       VELTINS-Arena   2006   19
# 2                                   Commerzbank-Arena   2006   13
# 3                                   Signal-Iduna-Park   2006   16
# 4                                    Volksparkstadion   2006   19
# ..                                                ...    ...  ...
# 59                          Al Bayt Stadium (Al Khor)   2022   19
# 60                     Lusail Iconic Stadium (Lusail)   2022   19
# 61                          Al Bayt Stadium (Al Khor)   2022   19
# 62  Khalifa International Stadium (Al Rayyan (Ar-R...   2022   15
# 63                     Lusail Iconic Stadium (Lusail)   2022   15
#
# [5926 rows x 68 columns]

# %%
matches_summary=pd.DataFrame({
    "Data type":matches.dtypes,
    "missing value":matches.isna().sum()
    }
)
n=len(matches_summary)
for i in range(n):
    print(matches_summary.iloc[i])
# Out:
# Data type        int64
# missing value        0
# Name: timestamp, dtype: object
# Data type        datetime64[ns]
# missing value                 0
# Name: date_GMT, dtype: object
# Data type        object
# missing value         0
# Name: status, dtype: object
# Data type        float64
# missing value       3821
# Name: attendance, dtype: object
# Data type        object
# missing value         0
# Name: home_team_name, dtype: object
# Data type        object
# missing value         0
# Name: away_team_name, dtype: object
# Data type        object
# missing value      4664
# Name: referee, dtype: object
# Data type        float64
# missing value       3839
# Name: Game Week, dtype: object
# Data type        float64
# missing value          0
# Name: Pre-Match PPG (Home), dtype: object
# Data type        float64
# missing value          0
# Name: Pre-Match PPG (Away), dtype: object
# Data type        float64
# missing value          0
# Name: home_ppg, dtype: object
# Data type        float64
# missing value          0
# Name: away_ppg, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_goal_count, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_goal_count, dtype: object
# Data type        int64
# missing value        0
# Name: total_goal_count, dtype: object
# Data type        int64
# missing value        0
# Name: total_goals_at_half_time, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_goal_count_half_time, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_goal_count_half_time, dtype: object
# Data type        object
# missing value      2309
# Name: home_team_goal_timings, dtype: object
# Data type        object
# missing value      2961
# Name: away_team_goal_timings, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_corner_count, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_corner_count, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_yellow_cards, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_red_cards, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_yellow_cards, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_red_cards, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_first_half_cards, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_second_half_cards, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_first_half_cards, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_second_half_cards, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_shots, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_shots, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_shots_on_target, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_shots_on_target, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_shots_off_target, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_shots_off_target, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_fouls, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_fouls, dtype: object
# Data type        int64
# missing value        0
# Name: home_team_possession, dtype: object
# Data type        int64
# missing value        0
# Name: away_team_possession, dtype: object
# Data type        float64
# missing value          0
# Name: Home Team Pre-Match xG, dtype: object
# Data type        float64
# missing value          0
# Name: Away Team Pre-Match xG, dtype: object
# Data type        float64
# missing value          0
# Name: team_a_xg, dtype: object
# Data type        float64
# missing value          0
# Name: team_b_xg, dtype: object
# Data type        float64
# missing value          0
# Name: average_goals_per_match_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: btts_percentage_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: over_15_percentage_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: over_25_percentage_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: over_35_percentage_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: over_45_percentage_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: over_15_HT_FHG_percentage_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: over_05_HT_FHG_percentage_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: over_15_2HG_percentage_pre_match, dtype: object
# Data type        int64
# missing value        0
# Name: over_05_2HG_percentage_pre_match, dtype: object
# Data type        float64
# missing value          0
# Name: average_corners_per_match_pre_match, dtype: object
# Data type        float64
# missing value          0
# Name: average_cards_per_match_pre_match, dtype: object
# Data type        float64
# missing value          0
# Name: odds_ft_home_team_win, dtype: object
# Data type        float64
# missing value          0
# Name: odds_ft_draw, dtype: object
# Data type        float64
# missing value          0
# Name: odds_ft_away_team_win, dtype: object
# Data type        float64
# missing value          0
# Name: odds_ft_over15, dtype: object
# Data type        float64
# missing value          0
# Name: odds_ft_over25, dtype: object
# Data type        float64
# missing value          0
# Name: odds_ft_over35, dtype: object
# Data type        float64
# missing value          0
# Name: odds_ft_over45, dtype: object
# Data type        float64
# missing value          0
# Name: odds_btts_yes, dtype: object
# Data type        float64
# missing value          0
# Name: odds_btts_no, dtype: object
# Data type        object
# missing value      1187
# Name: stadium_name, dtype: object
# Data type        int32
# missing value        0
# Name: season, dtype: object
# Data type        int32
# missing value        0
# Name: hour, dtype: object

# %%
matches=matches[["home_team_name","away_team_name","home_team_goal_count","away_team_goal_count","home_team_goal_count_half_time","away_team_goal_count_half_time","Home Team Pre-Match xG","Away Team Pre-Match xG","hour","season"]]
matches
# Out:
#          home_team_name away_team_name  home_team_goal_count  \
# 0               Germany     Costa Rica                     4
# 1                Poland        Ecuador                     0
# 2               England       Paraguay                     1
# 3   Trinidad and Tobago         Sweden                     0
# 4             Argentina    Ivory Coast                     2
# ..                  ...            ...                   ...
# 59              England         France                     1
# 60            Argentina        Croatia                     3
# 61               France        Morocco                     2
# 62              Croatia        Morocco                     2
# 63            Argentina         France                     3
#
#     away_team_goal_count  home_team_goal_count_half_time  \
# 0                      2                               2
# 1                      2                               0
# 2                      0                               1
# 3                      0                               0
# 4                      1                               2
# ..                   ...                             ...
# 59                     2                               0
# 60                     0                               2
# 61                     0                               1
# 62                     1                               2
# 63                     3                               2
#
#     away_team_goal_count_half_time  Home Team Pre-Match xG  \
# 0                                1                    0.00
# 1                                1                    0.00
# 2                                0                    0.00
# 3                                0                    0.00
# 4                                0                    0.00
# ..                             ...                     ...
# 59                               1                    1.50
# 60                               0                    1.62
# 61                               0                    1.81
# 62                               1                    1.27
# 63                               0                    1.56
#
#     Away Team Pre-Match xG  hour  season
# 0                     0.00    16    2006
# 1                     0.00    19    2006
# 2                     0.00    13    2006
# 3                     0.00    16    2006
# 4                     0.00    19    2006
# ..                     ...   ...     ...
# 59                    1.97    19    2022
# 60                    1.28    19    2022
# 61                    0.88    19    2022
# 62                    0.98    15    2022
# 63                    1.72    15    2022
#
# [5926 rows x 10 columns]

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1771 entries, 0 to 1770
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Current Club  1771 non-null   object
#  1   season        1771 non-null   float64
#  2   age           1771 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 41.6+ KB

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5926 entries, 0 to 63
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   home_team_name                  5926 non-null   object
#  1   away_team_name                  5926 non-null   object
#  2   home_team_goal_count            5926 non-null   int64
#  3   away_team_goal_count            5926 non-null   int64
#  4   home_team_goal_count_half_time  5926 non-null   int64
#  5   away_team_goal_count_half_time  5926 non-null   int64
#  6   Home Team Pre-Match xG          5926 non-null   float64
#  7   Away Team Pre-Match xG          5926 non-null   float64
#  8   hour                            5926 non-null   int32
#  9   season                          5926 non-null   int32
# dtypes: float64(2), int32(2), int64(4), object(2)
# memory usage: 463.0+ KB

# %%
matches=matches.merge(
    players,
    left_on=["home_team_name","season"],
    right_on=["Current Club","season"],
    how="left"
)
matches.rename(columns={"age": "home_team_age"}, inplace=True)
matches.drop(columns=["Current Club"], inplace=True)
matches=matches.merge(
    players,
    left_on=["away_team_name","season"],
    right_on=["Current Club","season"],
    how="left"
)
matches.rename(columns={"age": "away_team_age"}, inplace=True)
matches.drop(columns=["Current Club"], inplace=True)
matches
# Out:
#            home_team_name away_team_name  home_team_goal_count  \
# 0                 Germany     Costa Rica                     4
# 1                  Poland        Ecuador                     0
# 2                 England       Paraguay                     1
# 3     Trinidad and Tobago         Sweden                     0
# 4               Argentina    Ivory Coast                     2
# ...                   ...            ...                   ...
# 5921              England         France                     1
# 5922            Argentina        Croatia                     3
# 5923               France        Morocco                     2
# 5924              Croatia        Morocco                     2
# 5925            Argentina         France                     3
#
#       away_team_goal_count  home_team_goal_count_half_time  \
# 0                        2                               2
# 1                        2                               0
# 2                        0                               1
# 3                        0                               0
# 4                        1                               2
# ...                    ...                             ...
# 5921                     2                               0
# 5922                     0                               2
# 5923                     0                               1
# 5924                     1                               2
# 5925                     3                               2
#
#       away_team_goal_count_half_time  Home Team Pre-Match xG  \
# 0                                  1                    0.00
# 1                                  1                    0.00
# 2                                  0                    0.00
# 3                                  0                    0.00
# 4                                  0                    0.00
# ...                              ...                     ...
# 5921                               1                    1.50
# 5922                               0                    1.62
# 5923                               0                    1.81
# 5924                               1                    1.27
# 5925                               0                    1.56
#
#       Away Team Pre-Match xG  hour  season  home_team_age  away_team_age
# 0                       0.00    16    2006      26.956522      28.086957
# 1                       0.00    19    2006      27.173913      27.000000
# 2                       0.00    13    2006      25.869565      27.173913
# 3                       0.00    16    2006      29.565217      28.173913
# 4                       0.00    19    2006      26.565217      25.956522
# ...                      ...   ...     ...            ...            ...
# 5921                    1.97    19    2022      26.376471      27.452381
# 5922                    1.28    19    2022      27.491525      27.531915
# 5923                    0.88    19    2022      27.452381      26.809524
# 5924                    0.98    15    2022      27.531915      26.809524
# 5925                    1.72    15    2022      27.491525      27.452381
#
# [5926 rows x 12 columns]

# %%
print(players.loc[(players["Current Club"]=="Germany") & (players["season"]==2006),"age"])
# Out:
# 593    26.956522
# Name: age, dtype: float64

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5926 entries, 0 to 5925
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   home_team_name                  5926 non-null   object
#  1   away_team_name                  5926 non-null   object
#  2   home_team_goal_count            5926 non-null   int64
#  3   away_team_goal_count            5926 non-null   int64
#  4   home_team_goal_count_half_time  5926 non-null   int64
#  5   away_team_goal_count_half_time  5926 non-null   int64
#  6   Home Team Pre-Match xG          5926 non-null   float64
#  7   Away Team Pre-Match xG          5926 non-null   float64
#  8   hour                            5926 non-null   int32
#  9   season                          5926 non-null   int32
#  10  home_team_age                   4925 non-null   float64
#  11  away_team_age                   4852 non-null   float64
# dtypes: float64(4), int32(2), int64(4), object(2)
# memory usage: 509.4+ KB

# %%
matches=matches.dropna()
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4355 entries, 0 to 5925
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   home_team_name                  4355 non-null   object
#  1   away_team_name                  4355 non-null   object
#  2   home_team_goal_count            4355 non-null   int64
#  3   away_team_goal_count            4355 non-null   int64
#  4   home_team_goal_count_half_time  4355 non-null   int64
#  5   away_team_goal_count_half_time  4355 non-null   int64
#  6   Home Team Pre-Match xG          4355 non-null   float64
#  7   Away Team Pre-Match xG          4355 non-null   float64
#  8   hour                            4355 non-null   int32
#  9   season                          4355 non-null   int32
#  10  home_team_age                   4355 non-null   float64
#  11  away_team_age                   4355 non-null   float64
# dtypes: float64(4), int32(2), int64(4), object(2)
# memory usage: 408.3+ KB

# %%
df=pd.read_csv("../data/additional/players.csv")
df_value=pd.read_csv("../data/additional/player_valuations.csv")

# %%
df
# Out:
#        player_id  first_name      last_name                name  last_season  \
# 0             10    Miroslav          Klose      Miroslav Klose         2015
# 1             26       Roman   Weidenfeller  Roman Weidenfeller         2017
# 2             65     Dimitar       Berbatov    Dimitar Berbatov         2015
# 3             77         NaN          Lúcio               Lúcio         2012
# 4             80         Tom         Starke          Tom Starke         2017
# ...          ...         ...            ...                 ...          ...
# 37574    1494766     Saikuba          Jarju       Saikuba Jarju         2025
# 37575    1497653        Bara  Sapoko Ndiaye  Bara Sapoko Ndiaye         2025
# 37576    1500143      Moussa           Kone         Moussa Kone         2025
# 37577    1507561  Mouhamadou           Sall     Mouhamadou Sall         2025
# 37578    1510255      Miguel          Silva        Miguel Silva         2025
#
#        current_club_id         player_code    country_of_birth city_of_birth  \
# 0                  398      miroslav-klose              Poland         Opole
# 1                   16  roman-weidenfeller             Germany          Diez
# 2                 1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3                  506               lucio              Brazil      Brasília
# 4                   27          tom-starke  East Germany (GDR)       Freital
# ...                ...                 ...                 ...           ...
# 37574              152       saikuba-jarju                 NaN           NaN
# 37575               27  bara-sapoko-ndiaye                 NaN           NaN
# 37576             6646         moussa-kone       Cote d'Ivoire         Daloa
# 37577             3508     mouhamadou-sall                 NaN           NaN
# 37578              979        miguel-silva            Portugal     Guimarães
#
#       country_of_citizenship  ...            agent_name  \
# 0                    Germany  ...  ASBW Sport Marketing
# 1                    Germany  ...      Neubauer 13 GmbH
# 2                   Bulgaria  ...       CSKA-AS-23 Ltd.
# 3                     Brazil  ...                   NaN
# 4                    Germany  ...                   IFM
# ...                      ...  ...                   ...
# 37574             The Gambia  ...                   NaN
# 37575                Senegal  ...                   4FC
# 37576          Cote d'Ivoire  ...   Tamegnon Consulting
# 37577                Senegal  ...                   NaN
# 37578               Portugal  ...                   NaN
#
#                                                image_url international_caps  \
# 0      https://img.a.transfermarkt.technology/portrai...                NaN
# 1      https://img.a.transfermarkt.technology/portrai...                NaN
# 2      https://img.a.transfermarkt.technology/portrai...                NaN
# 3      https://img.a.transfermarkt.technology/portrai...                NaN
# 4      https://img.a.transfermarkt.technology/portrai...                NaN
# ...                                                  ...                ...
# 37574  https://img.a.transfermarkt.technology/portrai...                NaN
# 37575  https://img.a.transfermarkt.technology/portrai...                NaN
# 37576  https://img.a.transfermarkt.technology/portrai...                NaN
# 37577  https://img.a.transfermarkt.technology/portrai...                NaN
# 37578  https://img.a.transfermarkt.technology/portrai...                NaN
#
#       international_goals  current_national_team_id  \
# 0                     NaN                       NaN
# 1                     NaN                       NaN
# 2                     NaN                       NaN
# 3                     NaN                       NaN
# 4                     NaN                       NaN
# ...                   ...                       ...
# 37574                 NaN                       NaN
# 37575                 NaN                       NaN
# 37576                 NaN                       NaN
# 37577                 NaN                       NaN
# 37578                 NaN                       NaN
#
#                                                      url  \
# 0      https://www.transfermarkt.co.uk/miroslav-klose...
# 1      https://www.transfermarkt.co.uk/roman-weidenfe...
# 2      https://www.transfermarkt.co.uk/dimitar-berbat...
# 3      https://www.transfermarkt.co.uk/lucio/profil/s...
# 4      https://www.transfermarkt.co.uk/tom-starke/pro...
# ...                                                  ...
# 37574  https://www.transfermarkt.co.uk/saikuba-jarju/...
# 37575  https://www.transfermarkt.co.uk/bara-sapoko-nd...
# 37576  https://www.transfermarkt.co.uk/moussa-kone/pr...
# 37577  https://www.transfermarkt.co.uk/mouhamadou-sal...
# 37578  https://www.transfermarkt.co.uk/miguel-silva/p...
#
#       current_club_domestic_competition_id  \
# 0                                      IT1
# 1                                       L1
# 2                                      GR1
# 3                                      IT1
# 4                                       L1
# ...                                    ...
# 37574                                  TR1
# 37575                                   L1
# 37576                                  TR1
# 37577                                  BE1
# 37578                                  PO1
#
#                                        current_club_name  market_value_in_eur  \
# 0                          Società Sportiva Lazio S.p.A.            1000000.0
# 1                                      Borussia Dortmund             750000.0
# 2      Panthessalonikios Athlitikos Omilos Konstantin...            1000000.0
# 3                                 Juventus Football Club             200000.0
# 4                                      FC Bayern München             100000.0
# ...                                                  ...                  ...
# 37574                                         Samsunspor                  NaN
# 37575                                  FC Bayern München             300000.0
# 37576  Fatih Karagümrük Sportif Faaliyetler San. Tic....             100000.0
# 37577                      Sportvereniging Zulte Waregem             100000.0
# 37578                           Moreirense Futebol Clube             100000.0
#
#        highest_market_value_in_eur
# 0                       30000000.0
# 1                        8000000.0
# 2                       34500000.0
# 3                       24500000.0
# 4                        3000000.0
# ...                            ...
# 37574                          NaN
# 37575                     300000.0
# 37576                     100000.0
# 37577                     100000.0
# 37578                     100000.0
#
# [37579 rows x 26 columns]

# %%
df=df[["player_id","name"]]

# %%
df_value
# Out:
#         player_id        date  market_value_in_eur       current_club_name  \
# 0          405973  2000-01-20               150000                 Unknown
# 1          342216  2001-07-20               100000                 Unknown
# 2            3132  2003-12-09               400000             Dynamo Kyiv
# 3            6893  2003-12-15               900000             Galatasaray
# 4              10  2004-10-04              7000000        SV Werder Bremen
# ...           ...         ...                  ...                     ...
# 526180    1291835  2026-03-23               100000           Rukh Lviv U19
# 526181    1293298  2026-03-23               150000  Kryvbas Kryvyi Rig U19
# 526182    1293692  2026-03-23                50000       FC Oleksandriya-2
# 526183    1346771  2026-03-23               100000           Rukh Lviv U19
# 526184    1447744  2026-03-23               100000               Rukh Lviv
#
#         current_club_id player_club_domestic_competition_id
# 0                3057.0                                 BE1
# 1                1241.0                                 SC1
# 2                 126.0                                 TR1
# 3                 984.0                                 GB1
# 4                 398.0                                 IT1
# ...                 ...                                 ...
# 526180          83932.0                                 NaN
# 526181          93057.0                                 NaN
# 526182         120273.0                                 NaN
# 526183          83932.0                                 NaN
# 526184          48726.0                                UKR1
#
# [526185 rows x 6 columns]

# %%
df=df.merge(
    df_value[["market_value_in_eur","player_id"]],
    on="player_id",
    how="left"
)
df
# Out:
#         player_id                name  market_value_in_eur
# 0              10      Miroslav Klose            7000000.0
# 1              10      Miroslav Klose            9000000.0
# 2              10      Miroslav Klose           12000000.0
# 3              10      Miroslav Klose           15000000.0
# 4              10      Miroslav Klose           20000000.0
# ...           ...                 ...                  ...
# 530455    1494766       Saikuba Jarju                  NaN
# 530456    1497653  Bara Sapoko Ndiaye             300000.0
# 530457    1500143         Moussa Kone             100000.0
# 530458    1507561     Mouhamadou Sall             100000.0
# 530459    1510255        Miguel Silva             100000.0
#
# [530460 rows x 3 columns]

# %%
df=df.drop_duplicates(subset="player_id")
df=df.reset_index()
df=df.drop(columns=["index"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37579 entries, 0 to 37578
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   player_id            37579 non-null  int64
#  1   name                 37579 non-null  object
#  2   market_value_in_eur  32561 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 880.9+ KB

# %%
print(players_res[players_res["full_name"] == "Miroslav Klose"])
# Out:
#           full_name  age  birthday_GMT season Current Club
# 497  Miroslav Klose   44        1978.0   2006      Germany
# 485  Miroslav Klose   44        1978.0   2010      Germany
# 467  Miroslav Klose   44        1978.0   2002      Germany
# 510  Miroslav Klose   44        1978.0   2014      Germany

# %%
players_res["full_name"]=players_res["full_name"].str.lower().str.strip()
df["name"]=df["name"].str.lower().str.strip()
# Out:
# /tmp/ipykernel_6541/2234801557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players_res["full_name"]=players_res["full_name"].str.lower().str.strip()

# %%
players_res=players_res.merge(
    df[["name", "market_value_in_eur"]],
    left_on="full_name",
    right_on="name",
    how="left"
)
players_res
# Out:
#                             full_name  age  birthday_GMT season  Current Club  \
# 0                        aaron lennon   35        1987.0   2006       England
# 1         abdoulaye mu00e9u00eftu00e9   41        1980.0   2006   Ivory Coast
# 2               abdul kader keu00efta   41        1981.0   2006   Ivory Coast
# 3      abdulaziz mohammed al khathran   49        1973.0   2006  Saudi Arabia
# 4                    adékambi olufadé   42        1980.0   2006          Togo
# ...                               ...  ...           ...    ...           ...
# 66477                  yussuf poulsen   31        1994.0   2022       Denmark
# 66478                   yuto nagatomo   39        1986.0   2022         Japan
# 66479               zakaria aboukhlal   26        2000.0   2022       Morocco
# 66480                     zeno debast   22        2003.0   2022       Belgium
# 66481                łukasz skorupski   34        1991.0   2022        Poland
#
#                     name  market_value_in_eur
# 0           aaron lennon             300000.0
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                    NaN                  NaN
# 4                    NaN                  NaN
# ...                  ...                  ...
# 66477     yussuf poulsen              50000.0
# 66478      yuto nagatomo             150000.0
# 66479  zakaria aboukhlal             100000.0
# 66480        zeno debast             400000.0
# 66481                NaN                  NaN
#
# [66482 rows x 7 columns]

# %%
players_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66482 entries, 0 to 66481
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   full_name            66466 non-null  object
#  1   age                  66482 non-null  int64
#  2   birthday_GMT         66376 non-null  float64
#  3   season               66482 non-null  object
#  4   Current Club         66482 non-null  object
#  5   name                 26623 non-null  object
#  6   market_value_in_eur  22347 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 3.6+ MB

# %%
players_res=players_res.dropna(subset=["market_value_in_eur"])
players_res.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22347 entries, 0 to 66480
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   full_name            22347 non-null  object
#  1   age                  22347 non-null  int64
#  2   birthday_GMT         22341 non-null  float64
#  3   season               22347 non-null  object
#  4   Current Club         22347 non-null  object
#  5   name                 22347 non-null  object
#  6   market_value_in_eur  22347 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
players_res=players_res.groupby(["season","Current Club"])["market_value_in_eur"].sum()
players_res=players_res.reset_index()
players_res
# Out:
#          season Current Club  market_value_in_eur
# 0          2002      Belgium           25000000.0
# 1          2002      Croatia            2350000.0
# 2          2002      Denmark            3500000.0
# 3          2002      England          165000000.0
# 4          2002       France           20150000.0
# ...         ...          ...                  ...
# 1441  2016/2018       Uganda             200000.0
# 1442  2016/2018      Ukraine            9900000.0
# 1443  2016/2018   Uzbekistan            1725000.0
# 1444  2016/2018        Wales           11775000.0
# 1445  2016/2018       Zambia            1225000.0
#
# [1446 rows x 3 columns]

# %%
players=players_res.merge(
    players_res[["market_value_in_eur","season","Current Club"]],
    on=["season","Current Club"],
    how="left"
    
)
players
# Out:
#          season Current Club  market_value_in_eur_x  market_value_in_eur_y
# 0          2002      Belgium             25000000.0             25000000.0
# 1          2002      Croatia              2350000.0              2350000.0
# 2          2002      Denmark              3500000.0              3500000.0
# 3          2002      England            165000000.0            165000000.0
# 4          2002       France             20150000.0             20150000.0
# ...         ...          ...                    ...                    ...
# 1441  2016/2018       Uganda               200000.0               200000.0
# 1442  2016/2018      Ukraine              9900000.0              9900000.0
# 1443  2016/2018   Uzbekistan              1725000.0              1725000.0
# 1444  2016/2018        Wales             11775000.0             11775000.0
# 1445  2016/2018       Zambia              1225000.0              1225000.0
#
# [1446 rows x 4 columns]

# %%
players=players.drop(columns=["market_value_in_eur_y"])
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1446 entries, 0 to 1445
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   season                 1446 non-null   object
#  1   Current Club           1446 non-null   object
#  2   market_value_in_eur_x  1446 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 34.0+ KB

# %%
matches=matches.merge(
    players[["market_value_in_eur_x","season","Current Club"]]
        .rename(columns={"market_value_in_eur_x": "away_value"}),
    left_on=["season","away_team_name"],
    right_on=["season","Current Club"],
    how="left"
)
matches=matches.drop(columns=["Current Club"])
matches=matches.merge(
    players[["market_value_in_eur_x","season","Current Club"]]
        .rename(columns={"market_value_in_eur_x": "home_value"}),
    left_on=["season","home_team_name"],
    right_on=["season","Current Club"],
    how="left"
)
matches=matches.drop(columns=["Current Club"])
matches
# Out:
#            home_team_name away_team_name  home_team_goal_count  \
# 0                 Germany     Costa Rica                     4
# 1                  Poland        Ecuador                     0
# 2                 England       Paraguay                     1
# 3     Trinidad and Tobago         Sweden                     0
# 4               Argentina    Ivory Coast                     2
# ...                   ...            ...                   ...
# 4350              England         France                     1
# 4351            Argentina        Croatia                     3
# 4352               France        Morocco                     2
# 4353              Croatia        Morocco                     2
# 4354            Argentina         France                     3
#
#       away_team_goal_count  home_team_goal_count_half_time  \
# 0                        2                               2
# 1                        2                               0
# 2                        0                               1
# 3                        0                               0
# 4                        1                               2
# ...                    ...                             ...
# 4350                     2                               0
# 4351                     0                               2
# 4352                     0                               1
# 4353                     1                               2
# 4354                     3                               2
#
#       away_team_goal_count_half_time  Home Team Pre-Match xG  \
# 0                                  1                    0.00
# 1                                  1                    0.00
# 2                                  0                    0.00
# 3                                  0                    0.00
# 4                                  0                    0.00
# ...                              ...                     ...
# 4350                               1                    1.50
# 4351                               0                    1.62
# 4352                               0                    1.81
# 4353                               1                    1.27
# 4354                               0                    1.56
#
#       Away Team Pre-Match xG  hour season  home_team_age  away_team_age  \
# 0                       0.00    16   2006      26.956522      28.086957
# 1                       0.00    19   2006      27.173913      27.000000
# 2                       0.00    13   2006      25.869565      27.173913
# 3                       0.00    16   2006      29.565217      28.173913
# 4                       0.00    19   2006      26.565217      25.956522
# ...                      ...   ...    ...            ...            ...
# 4350                    1.97    19   2022      26.376471      27.452381
# 4351                    1.28    19   2022      27.491525      27.531915
# 4352                    0.88    19   2022      27.452381      26.809524
# 4353                    0.98    15   2022      27.531915      26.809524
# 4354                    1.72    15   2022      27.491525      27.452381
#
#       away_value   home_value
# 0            NaN   54650000.0
# 1      2250000.0    2350000.0
# 2     10330000.0  234100000.0
# 3     42750000.0      50000.0
# 4            NaN   14050000.0
# ...          ...          ...
# 4350  61725000.0   96150000.0
# 4351  15600000.0   71725000.0
# 4352  14150000.0   61725000.0
# 4353  14150000.0   15600000.0
# 4354  61725000.0   71725000.0
#
# [4355 rows x 14 columns]

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4355 entries, 0 to 4354
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   home_team_name                  4355 non-null   object
#  1   away_team_name                  4355 non-null   object
#  2   home_team_goal_count            4355 non-null   int64
#  3   away_team_goal_count            4355 non-null   int64
#  4   home_team_goal_count_half_time  4355 non-null   int64
#  5   away_team_goal_count_half_time  4355 non-null   int64
#  6   Home Team Pre-Match xG          4355 non-null   float64
#  7   Away Team Pre-Match xG          4355 non-null   float64
#  8   hour                            4355 non-null   int32
#  9   season                          4355 non-null   object
#  10  home_team_age                   4355 non-null   float64
#  11  away_team_age                   4355 non-null   float64
#  12  away_value                      3481 non-null   float64
#  13  home_value                      3545 non-null   float64
# dtypes: float64(6), int32(1), int64(4), object(3)
# memory usage: 459.4+ KB

# %%
matches=matches.dropna()
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3000 entries, 1 to 4354
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   home_team_name                  3000 non-null   object
#  1   away_team_name                  3000 non-null   object
#  2   home_team_goal_count            3000 non-null   int64
#  3   away_team_goal_count            3000 non-null   int64
#  4   home_team_goal_count_half_time  3000 non-null   int64
#  5   away_team_goal_count_half_time  3000 non-null   int64
#  6   Home Team Pre-Match xG          3000 non-null   float64
#  7   Away Team Pre-Match xG          3000 non-null   float64
#  8   hour                            3000 non-null   int32
#  9   season                          3000 non-null   object
#  10  home_team_age                   3000 non-null   float64
#  11  away_team_age                   3000 non-null   float64
#  12  away_value                      3000 non-null   float64
#  13  home_value                      3000 non-null   float64
# dtypes: float64(6), int32(1), int64(4), object(3)
# memory usage: 339.8+ KB

# %%
print(len(matches[(matches["Away Team Pre-Match xG"]==0) | (matches["Home Team Pre-Match xG"]==0)]))
print(len(matches[(matches["Away Team Pre-Match xG"]==0) & (matches["Home Team Pre-Match xG"]==0)]))
print(len(matches[(matches["away_team_goal_count"]==0) | (matches["home_team_goal_count"]==0)]))
print(len(matches[(matches["away_team_goal_count"]==0) & (matches["home_team_goal_count"]==0)]))
# Out:
# 1819
# 1422
# 1737
# 437

# %%
matches["away_value"]=matches["away_value"]/1e8
matches["home_value"]=matches["home_value"]/1e8
matches
# Out:
# /tmp/ipykernel_6541/4281075010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches["away_value"]=matches["away_value"]/1e8
# /tmp/ipykernel_6541/4281075010.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches["home_value"]=matches["home_value"]/1e8
#              home_team_name  away_team_name  home_team_goal_count  \
# 1                    Poland         Ecuador                     0
# 2                   England        Paraguay                     1
# 3       Trinidad and Tobago          Sweden                     0
# 5     Serbia and Montenegro     Netherlands                     0
# 9                     USMNT  Czech Republic                     0
# ...                     ...             ...                   ...
# 4350                England          France                     1
# 4351              Argentina         Croatia                     3
# 4352                 France         Morocco                     2
# 4353                Croatia         Morocco                     2
# 4354              Argentina          France                     3
#
#       away_team_goal_count  home_team_goal_count_half_time  \
# 1                        2                               0
# 2                        0                               1
# 3                        0                               0
# 5                        1                               0
# 9                        3                               0
# ...                    ...                             ...
# 4350                     2                               0
# 4351                     0                               2
# 4352                     0                               1
# 4353                     1                               2
# 4354                     3                               2
#
#       away_team_goal_count_half_time  Home Team Pre-Match xG  \
# 1                                  1                    0.00
# 2                                  0                    0.00
# 3                                  0                    0.00
# 5                                  1                    0.00
# 9                                  2                    0.00
# ...                              ...                     ...
# 4350                               1                    1.50
# 4351                               0                    1.62
# 4352                               0                    1.81
# 4353                               1                    1.27
# 4354                               0                    1.56
#
#       Away Team Pre-Match xG  hour season  home_team_age  away_team_age  \
# 1                       0.00    19   2006      27.173913      27.000000
# 2                       0.00    13   2006      25.869565      27.173913
# 3                       0.00    16   2006      29.565217      28.173913
# 5                       0.00    13   2006      28.478261      27.130435
# 9                       0.00    16   2006      28.608696      28.869565
# ...                      ...   ...    ...            ...            ...
# 4350                    1.97    19   2022      26.376471      27.452381
# 4351                    1.28    19   2022      27.491525      27.531915
# 4352                    0.88    19   2022      27.452381      26.809524
# 4353                    0.98    15   2022      27.531915      26.809524
# 4354                    1.72    15   2022      27.491525      27.452381
#
#       away_value  home_value
# 1        0.02250     0.02350
# 2        0.10330     2.34100
# 3        0.42750     0.00050
# 5        0.65050     0.06825
# 9        0.06000     0.05750
# ...          ...         ...
# 4350     0.61725     0.96150
# 4351     0.15600     0.71725
# 4352     0.14150     0.61725
# 4353     0.14150     0.15600
# 4354     0.61725     0.71725
#
# [3000 rows x 14 columns]

# %%
matches=matches.reset_index()
matches=matches.drop(columns=["index"])

# %%
matches=matches.drop(columns=["Away Team Pre-Match xG","Home Team Pre-Match xG","away_team_goal_count","home_team_goal_count","home_team_goal_count_half_time","away_team_goal_count_half_time"])
matches
# Out:
#              home_team_name  away_team_name  hour season  home_team_age  \
# 0                    Poland         Ecuador    19   2006      27.173913
# 1                   England        Paraguay    13   2006      25.869565
# 2       Trinidad and Tobago          Sweden    16   2006      29.565217
# 3     Serbia and Montenegro     Netherlands    13   2006      28.478261
# 4                     USMNT  Czech Republic    16   2006      28.608696
# ...                     ...             ...   ...    ...            ...
# 2995                England          France    19   2022      26.376471
# 2996              Argentina         Croatia    19   2022      27.491525
# 2997                 France         Morocco    19   2022      27.452381
# 2998                Croatia         Morocco    15   2022      27.531915
# 2999              Argentina          France    15   2022      27.491525
#
#       away_team_age  away_value  home_value
# 0         27.000000     0.02250     0.02350
# 1         27.173913     0.10330     2.34100
# 2         28.173913     0.42750     0.00050
# 3         27.130435     0.65050     0.06825
# 4         28.869565     0.06000     0.05750
# ...             ...         ...         ...
# 2995      27.452381     0.61725     0.96150
# 2996      27.531915     0.15600     0.71725
# 2997      26.809524     0.14150     0.61725
# 2998      26.809524     0.14150     0.15600
# 2999      27.452381     0.61725     0.71725
#
# [3000 rows x 8 columns]

# %%
rank=pd.read_csv("../data/fifa_ranking-2024-06-20.csv")
rank
# Out:
#         rank       country_full country_abrv  total_points  previous_points  \
# 0      140.0  Brunei Darussalam          BRU          2.00             0.00
# 1       33.0           Portugal          POR         38.00             0.00
# 2       32.0             Zambia          ZAM         38.00             0.00
# 3       31.0             Greece          GRE         38.00             0.00
# 4       30.0            Algeria          ALG         39.00             0.00
# ...      ...                ...          ...           ...              ...
# 67467  137.0             Kuwait          KUW       1098.42          1085.46
# 67468  136.0          Lithuania          LTU       1100.66          1095.23
# 67469  135.0           Malaysia          MAS       1107.58          1094.54
# 67470  133.0    Solomon Islands          SOL       1111.02          1111.02
# 67471    1.0          Argentina          ARG       1860.14          1858.00
#
#        rank_change confederation   rank_date
# 0              140           AFC  1992-12-31
# 1               33          UEFA  1992-12-31
# 2               32           CAF  1992-12-31
# 3               31          UEFA  1992-12-31
# 4               30           CAF  1992-12-31
# ...            ...           ...         ...
# 67467           -2           AFC  2024-06-20
# 67468           -1          UEFA  2024-06-20
# 67469           -3           AFC  2024-06-20
# 67470            1           OFC  2024-06-20
# 67471            0      CONMEBOL  2024-06-20
#
# [67472 rows x 8 columns]

# %%
rank["rank_date"]=pd.to_datetime(rank["rank_date"],errors="coerce")
rank["rank_date"]=rank["rank_date"].dt.year
rank["rank_date"]=pd.to_numeric(rank["rank_date"],errors="coerce")
rank=rank.rename(columns={"rank_date":"season"})
rank=rank[rank["season"]>=2001]
rank
# Out:
#         rank       country_full country_abrv  total_points  previous_points  \
# 14987  198.0  US Virgin Islands          VIR         33.00            33.00
# 14988   92.0            Armenia          ARM        441.00           441.00
# 14989   91.0              Gabon          GAB        442.00           442.00
# 14990   90.0        New Zealand          NZL        443.00           441.00
# 14991   89.0            Liberia          LBR        448.00           428.00
# ...      ...                ...          ...           ...              ...
# 67467  137.0             Kuwait          KUW       1098.42          1085.46
# 67468  136.0          Lithuania          LTU       1100.66          1095.23
# 67469  135.0           Malaysia          MAS       1107.58          1094.54
# 67470  133.0    Solomon Islands          SOL       1111.02          1111.02
# 67471    1.0          Argentina          ARG       1860.14          1858.00
#
#        rank_change confederation  season
# 14987            0      CONCACAF    2001
# 14988            2          UEFA    2001
# 14989            2           CAF    2001
# 14990           -1           OFC    2001
# 14991           -6           CAF    2001
# ...            ...           ...     ...
# 67467           -2           AFC    2024
# 67468           -1          UEFA    2024
# 67469           -3           AFC    2024
# 67470            1           OFC    2024
# 67471            0      CONMEBOL    2024
#
# [52485 rows x 8 columns]

# %%
rank=rank.reset_index()
rank=rank.drop(columns=["index"])
rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52485 entries, 0 to 52484
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   rank             52476 non-null  float64
#  1   country_full     52485 non-null  object
#  2   country_abrv     52485 non-null  object
#  3   total_points     52485 non-null  float64
#  4   previous_points  52485 non-null  float64
#  5   rank_change      52485 non-null  int64
#  6   confederation    52485 non-null  object
#  7   season           52485 non-null  int32
# dtypes: float64(3), int32(1), int64(1), object(3)
# memory usage: 3.0+ MB
